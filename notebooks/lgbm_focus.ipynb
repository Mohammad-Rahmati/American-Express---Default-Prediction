# %%
import warnings
warnings.filterwarnings('ignore')

from evaluation_metric import lgb_amex_metric
import os
import gc
import random
import numpy as np
import pandas as pd
import joblib
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import ParameterGrid
from sklearn.calibration import CalibratedClassifierCV
import lightgbm as lgb

main_fold = 1

class CFG:
    input_dir = 'Data/'
    seed = 42
    n_folds = 5
    target = 'target'

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

def save_model(fold):
    def callback(env):
        global max_score
        iteration = env.iteration
        score = env.evaluation_result_list[0][2]
        if iteration % 200 == 0:
            print('iteration {}, score= {:.05f}, max_score= {:.05f}'.format(iteration,score, max_score))
        if score > max_score:
            max_score = score
            path = 'Models/'
            for fname in os.listdir(path):
                if fname.startswith("fold_{}_{}".format(main_fold, fold)):
                    os.remove(os.path.join(path, fname))

            print('High Score: iteration {}, score={:.05f}'.format(iteration, score))
            joblib.dump(env.model, 'Models/fold_{}_{}_iter_{}_score_{:.05f}.pkl'.format(main_fold, fold, iteration, score))

    callback.order = 0
    return callback

cat_features = [
    "B_30",
    "B_38",
    "D_114",
    "D_116",
    "D_117",
    "D_120",
    "D_126",
    "D_63",
    "D_64",
    "D_66",
    "D_68"
]
cat_features = [f"{cf}_last" for cf in cat_features]

# %%
x_train = pd.read_pickle('Output/x_train_fold_{}.pkl'.format(main_fold))
x_val = pd.read_pickle('Output/x_val_fold_{}.pkl'.format(main_fold))
y_train = pd.read_pickle('Output/y_train_fold_{}.pkl'.format(main_fold))
y_val = pd.read_pickle('Output/y_val_fold_{}.pkl'.format(main_fold))

x_train.shape, x_val.shape, y_train.shape, y_val.shape
# Out:
# ((367130, 1103), (91783, 1103), (367130,), (91783,))

# %%
val = pd.concat([x_val, y_val], axis=1)
val.shape
# Out:
# (91783, 1104)

# %%
def train_and_evaluate(x_train_org, y_train_org, val, parameters):
    global max_score
    
    kfold = StratifiedKFold(n_splits = CFG.n_folds, shuffle = True, random_state = CFG.seed)
    for fold, (trn_ind, val_ind) in enumerate(kfold.split(val, val[CFG.target])):
        
        max_score = 0.785
        print(' ')
        features = [col for col in x_train_org.columns if col not in ['target']]
        print(f'Training fold {fold} with {len(features)} features...')
        x_train, x_val = val[features].iloc[trn_ind], val[features].iloc[val_ind]
        y_train, y_val = val[CFG.target].iloc[trn_ind], val[CFG.target].iloc[val_ind]
        x_train_new = pd.concat([x_train_org, x_train], axis=0)
        y_train_new = pd.concat([y_train_org, y_train], axis=0)
    
        lgb_train = lgb.Dataset(x_train_new, y_train_new, categorical_feature = cat_features)
        lgb_valid = lgb.Dataset(x_val, y_val, categorical_feature = cat_features)
        del x_train, x_val, y_train, y_val, x_train_new, y_train_new; gc.collect()
            
        model = lgb.train(
            params = parameters,
            train_set = lgb_train,
            num_boost_round = 12000,
            valid_sets = [lgb_valid],
            feval = lgb_amex_metric,
            callbacks=[save_model(fold)],
            )

        path = 'Models/'
        for fname in os.listdir(path):
            if fname.startswith("fold_{}_{}".format(main_fold, fold)):
                model = joblib.load('Models/' + fname)
                model.save_model('Models/cp_{}_{}_model.txt'.format(main_fold, fold))

# %%
params = {
    'objective': 'binary',
    'metric':'None',
    'boosting': 'dart',
    'seed': CFG.seed,
    'num_leaves': 100,
    'learning_rate': 0.01,
    'drop_rate': 0.1,
    'feature_fraction': 0.20,
    'bagging_freq': 10,
    'bagging_fraction': 0.50,
    'n_jobs': -1,
    'lambda_l2': 2,
    'min_data_in_leaf': 40
}

# params = {
#     'objective': ['binary'],
#     'metric': ['amex_metric'],
#     'boosting': ['dart'],
#     'seed': [42],
#     'num_leaves': [25, 50, 100, 250, 500, 1000],
#     'learning_rate': [0.01, 0.005],
#     'drop_rate': [0.01, 0.025, 0.05, 0.1, 0.2],
#     'feature_fraction': [0.20,0.30],
#     'bagging_freq': [10],
#     'bagging_fraction': [0.50,0.60],
#     'n_jobs': [-1],
#     'lambda_l2': [2],
#     'min_data_in_leaf': [40]
#     }

# %%
train_and_evaluate(x_train, y_train, val, params)
# Out:
#
# Training fold 0 with 1103 features...
# [LightGBM] [Info] Number of positive: 114075, number of negative: 326481
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.939682 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 187460
# [LightGBM] [Info] Number of data points in the train set: 440556, number of used features: 1095
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258934 -> initscore=-1.051516
# [LightGBM] [Info] Start training from score -1.051516
# iteration 0, score= 0.70516, max_score= 0.78500
# iteration 200, score= 0.75757, max_score= 0.78500
# iteration 400, score= 0.76201, max_score= 0.78500
# iteration 600, score= 0.76402, max_score= 0.78500
# iteration 800, score= 0.76915, max_score= 0.78500
# iteration 1000, score= 0.77285, max_score= 0.78500
# iteration 1200, score= 0.77677, max_score= 0.78500
# iteration 1400, score= 0.77801, max_score= 0.78500
# iteration 1600, score= 0.77863, max_score= 0.78500
# iteration 1800, score= 0.78057, max_score= 0.78500
# iteration 2000, score= 0.78301, max_score= 0.78500
# iteration 2200, score= 0.78337, max_score= 0.78500
# iteration 2400, score= 0.78409, max_score= 0.78500
# High Score: iteration 2405, score=0.78504
# High Score: iteration 2406, score=0.78505
# High Score: iteration 2407, score=0.78505
# High Score: iteration 2408, score=0.78516
# High Score: iteration 2432, score=0.78528
# High Score: iteration 2433, score=0.78539
# High Score: iteration 2540, score=0.78589
# High Score: iteration 2542, score=0.78589
# High Score: iteration 2543, score=0.78589
# High Score: iteration 2544, score=0.78589
# High Score: iteration 2549, score=0.78589
# High Score: iteration 2550, score=0.78589
# High Score: iteration 2551, score=0.78589
# High Score: iteration 2552, score=0.78589
# High Score: iteration 2553, score=0.78590
# High Score: iteration 2554, score=0.78590
# High Score: iteration 2555, score=0.78590
# High Score: iteration 2581, score=0.78602
# High Score: iteration 2582, score=0.78602
# High Score: iteration 2583, score=0.78602
# High Score: iteration 2589, score=0.78613
# High Score: iteration 2590, score=0.78623
# High Score: iteration 2591, score=0.78624
# iteration 2600, score= 0.78593, max_score= 0.78624
# High Score: iteration 2661, score=0.78627
# High Score: iteration 2675, score=0.78630
# High Score: iteration 2683, score=0.78652
# High Score: iteration 2741, score=0.78687
# High Score: iteration 2742, score=0.78687
# High Score: iteration 2743, score=0.78687
# High Score: iteration 2772, score=0.78688
# High Score: iteration 2773, score=0.78699
# High Score: iteration 2774, score=0.78699
# High Score: iteration 2775, score=0.78699
# High Score: iteration 2782, score=0.78710
# High Score: iteration 2784, score=0.78731
# iteration 2800, score= 0.78711, max_score= 0.78731
# High Score: iteration 2813, score=0.78733
# High Score: iteration 2817, score=0.78734
# High Score: iteration 2820, score=0.78745
# High Score: iteration 2822, score=0.78755
# High Score: iteration 2823, score=0.78755
# High Score: iteration 2824, score=0.78755
# High Score: iteration 2825, score=0.78776
# High Score: iteration 2826, score=0.78786
# High Score: iteration 2829, score=0.78818
# iteration 3000, score= 0.78684, max_score= 0.78818
# High Score: iteration 3116, score=0.78819
# High Score: iteration 3117, score=0.78819
# High Score: iteration 3118, score=0.78819
# iteration 3200, score= 0.78699, max_score= 0.78819
# High Score: iteration 3380, score=0.78825
# High Score: iteration 3381, score=0.78825
# iteration 3400, score= 0.78753, max_score= 0.78825
# High Score: iteration 3445, score=0.78850
# iteration 3600, score= 0.78699, max_score= 0.78850
# High Score: iteration 3714, score=0.78872
# High Score: iteration 3715, score=0.78872
# High Score: iteration 3716, score=0.78872
# High Score: iteration 3717, score=0.78872
# High Score: iteration 3722, score=0.78873
# High Score: iteration 3723, score=0.78873
# High Score: iteration 3724, score=0.78873
# High Score: iteration 3725, score=0.78873
# iteration 3800, score= 0.78835, max_score= 0.78873
# High Score: iteration 3851, score=0.78878
# High Score: iteration 3872, score=0.78879
# High Score: iteration 3873, score=0.78879
# High Score: iteration 3877, score=0.78879
# High Score: iteration 3891, score=0.78880
# High Score: iteration 3893, score=0.78880
# High Score: iteration 3894, score=0.78880
# High Score: iteration 3895, score=0.78880
# High Score: iteration 3896, score=0.78881
# High Score: iteration 3897, score=0.78881
# High Score: iteration 3899, score=0.78882
# High Score: iteration 3900, score=0.78882
# High Score: iteration 3903, score=0.78882
# High Score: iteration 3904, score=0.78882
# High Score: iteration 3905, score=0.78882
# High Score: iteration 3906, score=0.78882
# High Score: iteration 3907, score=0.78882
# High Score: iteration 3908, score=0.78882
# High Score: iteration 3913, score=0.78903
# High Score: iteration 3914, score=0.78903
# High Score: iteration 3917, score=0.78903
# High Score: iteration 3918, score=0.78903
# High Score: iteration 3926, score=0.78923
# High Score: iteration 3927, score=0.78923
# High Score: iteration 3928, score=0.78934
# High Score: iteration 3945, score=0.78945
# High Score: iteration 3946, score=0.78945
# iteration 4000, score= 0.78885, max_score= 0.78945
# High Score: iteration 4064, score=0.78952
# High Score: iteration 4065, score=0.78983
# High Score: iteration 4069, score=0.79015
# High Score: iteration 4073, score=0.79026
# High Score: iteration 4074, score=0.79036
# High Score: iteration 4077, score=0.79068
# High Score: iteration 4088, score=0.79089
# High Score: iteration 4089, score=0.79100
# High Score: iteration 4090, score=0.79100
# High Score: iteration 4091, score=0.79101
# High Score: iteration 4169, score=0.79105
# High Score: iteration 4170, score=0.79105
# High Score: iteration 4171, score=0.79105
# High Score: iteration 4172, score=0.79105
# High Score: iteration 4173, score=0.79106
# High Score: iteration 4174, score=0.79106
# High Score: iteration 4175, score=0.79106
# High Score: iteration 4176, score=0.79106
# High Score: iteration 4179, score=0.79116
# High Score: iteration 4195, score=0.79116
# iteration 4200, score= 0.79043, max_score= 0.79116
# iteration 4400, score= 0.79052, max_score= 0.79116
# High Score: iteration 4406, score=0.79147
# High Score: iteration 4407, score=0.79158
# High Score: iteration 4459, score=0.79159
# High Score: iteration 4460, score=0.79159
# High Score: iteration 4461, score=0.79159
# High Score: iteration 4462, score=0.79169
# High Score: iteration 4463, score=0.79169
# High Score: iteration 4472, score=0.79180
# High Score: iteration 4478, score=0.79190
# High Score: iteration 4479, score=0.79190
# High Score: iteration 4481, score=0.79190
# High Score: iteration 4484, score=0.79201
# High Score: iteration 4485, score=0.79201
# High Score: iteration 4490, score=0.79232
# High Score: iteration 4491, score=0.79242
# iteration 4600, score= 0.79162, max_score= 0.79242
# High Score: iteration 4645, score=0.79247
# High Score: iteration 4646, score=0.79247
# High Score: iteration 4647, score=0.79247
# High Score: iteration 4674, score=0.79248
# High Score: iteration 4676, score=0.79258
# High Score: iteration 4678, score=0.79258
# High Score: iteration 4691, score=0.79259
# High Score: iteration 4692, score=0.79259
# High Score: iteration 4693, score=0.79259
# High Score: iteration 4694, score=0.79259
# High Score: iteration 4710, score=0.79261
# High Score: iteration 4711, score=0.79261
# High Score: iteration 4716, score=0.79292
# iteration 4800, score= 0.79221, max_score= 0.79292
# High Score: iteration 4982, score=0.79310
# iteration 5000, score= 0.79205, max_score= 0.79310
# High Score: iteration 5012, score=0.79311
# High Score: iteration 5053, score=0.79345
# High Score: iteration 5058, score=0.79345
# High Score: iteration 5072, score=0.79345
# High Score: iteration 5073, score=0.79345
# High Score: iteration 5075, score=0.79367
# High Score: iteration 5141, score=0.79377
# High Score: iteration 5142, score=0.79377
# High Score: iteration 5148, score=0.79387
# iteration 5200, score= 0.79356, max_score= 0.79387
# High Score: iteration 5288, score=0.79390
# High Score: iteration 5335, score=0.79390
# High Score: iteration 5336, score=0.79400
# High Score: iteration 5346, score=0.79442
# High Score: iteration 5347, score=0.79442
# High Score: iteration 5348, score=0.79443
# High Score: iteration 5350, score=0.79463
# High Score: iteration 5351, score=0.79474
# High Score: iteration 5376, score=0.79475
# iteration 5400, score= 0.79371, max_score= 0.79475
# High Score: iteration 5461, score=0.79488
# iteration 5600, score= 0.79353, max_score= 0.79488
# iteration 5800, score= 0.79374, max_score= 0.79488
# High Score: iteration 5807, score=0.79490
# High Score: iteration 5818, score=0.79522
# High Score: iteration 5819, score=0.79522
# High Score: iteration 5842, score=0.79533
# High Score: iteration 5908, score=0.79542
# High Score: iteration 5911, score=0.79542
# High Score: iteration 5975, score=0.79543
# High Score: iteration 5977, score=0.79554
# High Score: iteration 5978, score=0.79554
# High Score: iteration 5990, score=0.79554
# High Score: iteration 5991, score=0.79554
# iteration 6000, score= 0.79534, max_score= 0.79554
# High Score: iteration 6152, score=0.79568
# High Score: iteration 6154, score=0.79568
# iteration 6200, score= 0.79464, max_score= 0.79568
# iteration 6400, score= 0.79446, max_score= 0.79568
# iteration 6600, score= 0.79321, max_score= 0.79568
# iteration 6800, score= 0.79199, max_score= 0.79568
# iteration 7000, score= 0.79225, max_score= 0.79568
# iteration 7200, score= 0.79119, max_score= 0.79568
# iteration 7400, score= 0.79174, max_score= 0.79568
# iteration 7600, score= 0.79091, max_score= 0.79568
# iteration 7800, score= 0.79113, max_score= 0.79568
# iteration 8000, score= 0.79159, max_score= 0.79568
# iteration 8200, score= 0.79191, max_score= 0.79568
# iteration 8400, score= 0.79170, max_score= 0.79568
# iteration 8600, score= 0.79152, max_score= 0.79568
# iteration 8800, score= 0.79175, max_score= 0.79568
# iteration 9000, score= 0.79153, max_score= 0.79568
# iteration 9200, score= 0.79224, max_score= 0.79568
# iteration 9400, score= 0.79223, max_score= 0.79568
# iteration 9600, score= 0.79243, max_score= 0.79568
# iteration 9800, score= 0.79296, max_score= 0.79568
# iteration 10000, score= 0.79234, max_score= 0.79568
# iteration 10200, score= 0.79299, max_score= 0.79568
# iteration 10400, score= 0.79269, max_score= 0.79568
# iteration 10600, score= 0.79218, max_score= 0.79568
# iteration 10800, score= 0.79303, max_score= 0.79568
# iteration 11000, score= 0.79237, max_score= 0.79568
# iteration 11200, score= 0.79238, max_score= 0.79568
# iteration 11400, score= 0.79279, max_score= 0.79568
# iteration 11600, score= 0.79248, max_score= 0.79568
# iteration 11800, score= 0.79319, max_score= 0.79568
#
# Training fold 1 with 1103 features...
# [LightGBM] [Info] Number of positive: 114075, number of negative: 326481
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 1.159793 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 187496
# [LightGBM] [Info] Number of data points in the train set: 440556, number of used features: 1095
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258934 -> initscore=-1.051516
# [LightGBM] [Info] Start training from score -1.051516
# iteration 0, score= 0.70781, max_score= 0.78500
# iteration 200, score= 0.75081, max_score= 0.78500
# iteration 400, score= 0.75568, max_score= 0.78500
# iteration 600, score= 0.75992, max_score= 0.78500
# iteration 800, score= 0.76109, max_score= 0.78500
# iteration 1000, score= 0.76561, max_score= 0.78500
# iteration 1200, score= 0.77103, max_score= 0.78500
# iteration 1400, score= 0.77464, max_score= 0.78500
# iteration 1600, score= 0.77797, max_score= 0.78500
# iteration 1800, score= 0.77943, max_score= 0.78500
# iteration 2000, score= 0.78147, max_score= 0.78500
# iteration 2200, score= 0.78191, max_score= 0.78500
# iteration 2400, score= 0.78227, max_score= 0.78500
# iteration 2600, score= 0.78316, max_score= 0.78500
# iteration 2800, score= 0.78339, max_score= 0.78500
# iteration 3000, score= 0.78421, max_score= 0.78500
# High Score: iteration 3161, score=0.78506
# High Score: iteration 3175, score=0.78507
# High Score: iteration 3176, score=0.78518
# High Score: iteration 3183, score=0.78519
# High Score: iteration 3184, score=0.78519
# High Score: iteration 3185, score=0.78519
# High Score: iteration 3186, score=0.78519
# High Score: iteration 3189, score=0.78529
# High Score: iteration 3191, score=0.78561
# High Score: iteration 3192, score=0.78561
# iteration 3200, score= 0.78457, max_score= 0.78561
# High Score: iteration 3252, score=0.78566
# High Score: iteration 3253, score=0.78566
# High Score: iteration 3254, score=0.78566
# High Score: iteration 3255, score=0.78566
# High Score: iteration 3256, score=0.78566
# High Score: iteration 3262, score=0.78566
# High Score: iteration 3263, score=0.78566
# High Score: iteration 3265, score=0.78566
# High Score: iteration 3270, score=0.78567
# High Score: iteration 3271, score=0.78567
# High Score: iteration 3273, score=0.78567
# High Score: iteration 3274, score=0.78567
# High Score: iteration 3275, score=0.78567
# High Score: iteration 3276, score=0.78567
# High Score: iteration 3280, score=0.78598
# High Score: iteration 3282, score=0.78609
# High Score: iteration 3283, score=0.78609
# High Score: iteration 3284, score=0.78609
# High Score: iteration 3293, score=0.78610
# High Score: iteration 3294, score=0.78641
# High Score: iteration 3296, score=0.78652
# High Score: iteration 3297, score=0.78652
# High Score: iteration 3301, score=0.78674
# High Score: iteration 3302, score=0.78674
# iteration 3400, score= 0.78500, max_score= 0.78674
# iteration 3600, score= 0.78510, max_score= 0.78674
# iteration 3800, score= 0.78540, max_score= 0.78674
# iteration 4000, score= 0.78568, max_score= 0.78674
# High Score: iteration 4135, score=0.78680
# iteration 4200, score= 0.78578, max_score= 0.78680
# High Score: iteration 4357, score=0.78699
# High Score: iteration 4362, score=0.78699
# High Score: iteration 4370, score=0.78711
# iteration 4400, score= 0.78617, max_score= 0.78711
# High Score: iteration 4518, score=0.78737
# iteration 4600, score= 0.78613, max_score= 0.78737
# iteration 4800, score= 0.78640, max_score= 0.78737
# High Score: iteration 4892, score=0.78746
# High Score: iteration 4893, score=0.78757
# High Score: iteration 4894, score=0.78757
# High Score: iteration 4895, score=0.78757
# High Score: iteration 4897, score=0.78757
# High Score: iteration 4899, score=0.78778
# High Score: iteration 4900, score=0.78778
# High Score: iteration 4901, score=0.78799
# High Score: iteration 4904, score=0.78800
# High Score: iteration 4914, score=0.78800
# High Score: iteration 4915, score=0.78810
# High Score: iteration 4916, score=0.78810
# High Score: iteration 4925, score=0.78821
# High Score: iteration 4926, score=0.78821
# High Score: iteration 4982, score=0.78840
# High Score: iteration 4983, score=0.78840
# High Score: iteration 4984, score=0.78840
# High Score: iteration 4985, score=0.78840
# High Score: iteration 4986, score=0.78841
# iteration 5000, score= 0.78831, max_score= 0.78841
# High Score: iteration 5001, score=0.78842
# High Score: iteration 5003, score=0.78842
# High Score: iteration 5006, score=0.78842
# High Score: iteration 5007, score=0.78843
# High Score: iteration 5182, score=0.78853
# High Score: iteration 5183, score=0.78853
# High Score: iteration 5184, score=0.78863
# High Score: iteration 5186, score=0.78874
# High Score: iteration 5187, score=0.78874
# High Score: iteration 5188, score=0.78884
# High Score: iteration 5190, score=0.78905
# High Score: iteration 5192, score=0.78916
# High Score: iteration 5195, score=0.78927
# iteration 5200, score= 0.78916, max_score= 0.78927
# High Score: iteration 5204, score=0.78948
# High Score: iteration 5205, score=0.78948
# iteration 5400, score= 0.78914, max_score= 0.78948
# High Score: iteration 5589, score=0.78951
# iteration 5600, score= 0.78909, max_score= 0.78951
# High Score: iteration 5668, score=0.78953
# High Score: iteration 5669, score=0.78953
# High Score: iteration 5671, score=0.78974
# High Score: iteration 5672, score=0.78974
# High Score: iteration 5673, score=0.78984
# High Score: iteration 5674, score=0.78984
# High Score: iteration 5675, score=0.79005
# High Score: iteration 5676, score=0.79005
# High Score: iteration 5677, score=0.79005
# iteration 5800, score= 0.78904, max_score= 0.79005
# iteration 6000, score= 0.78918, max_score= 0.79005
# High Score: iteration 6185, score=0.79010
# iteration 6200, score= 0.78946, max_score= 0.79010
# iteration 6400, score= 0.78895, max_score= 0.79010
# iteration 6600, score= 0.78741, max_score= 0.79010
# iteration 6800, score= 0.78805, max_score= 0.79010
# iteration 7000, score= 0.78756, max_score= 0.79010
# iteration 7200, score= 0.78825, max_score= 0.79010
# iteration 7400, score= 0.78880, max_score= 0.79010
# iteration 7600, score= 0.78883, max_score= 0.79010
# iteration 7800, score= 0.78883, max_score= 0.79010
# iteration 8000, score= 0.78830, max_score= 0.79010
# iteration 8200, score= 0.78662, max_score= 0.79010
# iteration 8400, score= 0.78642, max_score= 0.79010
# iteration 8600, score= 0.78527, max_score= 0.79010
# iteration 8800, score= 0.78676, max_score= 0.79010
# iteration 9000, score= 0.78645, max_score= 0.79010
# iteration 9200, score= 0.78675, max_score= 0.79010
# iteration 9400, score= 0.78652, max_score= 0.79010
# iteration 9600, score= 0.78601, max_score= 0.79010
# iteration 9800, score= 0.78610, max_score= 0.79010
# iteration 10000, score= 0.78589, max_score= 0.79010
# iteration 10200, score= 0.78557, max_score= 0.79010
# iteration 10400, score= 0.78652, max_score= 0.79010
# iteration 10600, score= 0.78625, max_score= 0.79010
# iteration 10800, score= 0.78595, max_score= 0.79010
# iteration 11000, score= 0.78628, max_score= 0.79010
# iteration 11200, score= 0.78680, max_score= 0.79010
# iteration 11400, score= 0.78649, max_score= 0.79010
# iteration 11600, score= 0.78680, max_score= 0.79010
# iteration 11800, score= 0.78680, max_score= 0.79010
#
# Training fold 2 with 1103 features...
# [LightGBM] [Info] Number of positive: 114074, number of negative: 326482
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.903682 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 187469
# [LightGBM] [Info] Number of data points in the train set: 440556, number of used features: 1095
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258932 -> initscore=-1.051527
# [LightGBM] [Info] Start training from score -1.051527
# iteration 0, score= 0.70043, max_score= 0.78500
# iteration 200, score= 0.75341, max_score= 0.78500
# iteration 400, score= 0.75889, max_score= 0.78500
# iteration 600, score= 0.76002, max_score= 0.78500
# iteration 800, score= 0.76417, max_score= 0.78500
# iteration 1000, score= 0.76592, max_score= 0.78500
# iteration 1200, score= 0.76735, max_score= 0.78500
# iteration 1400, score= 0.77006, max_score= 0.78500
# iteration 1600, score= 0.77409, max_score= 0.78500
# iteration 1800, score= 0.77481, max_score= 0.78500
# iteration 2000, score= 0.77496, max_score= 0.78500
# iteration 2200, score= 0.77674, max_score= 0.78500
# iteration 2400, score= 0.77760, max_score= 0.78500
# iteration 2600, score= 0.77760, max_score= 0.78500
# iteration 2800, score= 0.77934, max_score= 0.78500
# iteration 3000, score= 0.78051, max_score= 0.78500
# iteration 3200, score= 0.78004, max_score= 0.78500
# iteration 3400, score= 0.78008, max_score= 0.78500
# iteration 3600, score= 0.78070, max_score= 0.78500
# iteration 3800, score= 0.78299, max_score= 0.78500
# iteration 4000, score= 0.78150, max_score= 0.78500
# iteration 4200, score= 0.78299, max_score= 0.78500
# iteration 4400, score= 0.78402, max_score= 0.78500
# High Score: iteration 4423, score=0.78519
# High Score: iteration 4424, score=0.78529
# High Score: iteration 4425, score=0.78540
# High Score: iteration 4522, score=0.78553
# High Score: iteration 4523, score=0.78553
# High Score: iteration 4527, score=0.78574
# High Score: iteration 4528, score=0.78585
# High Score: iteration 4537, score=0.78597
# High Score: iteration 4590, score=0.78609
# iteration 4600, score= 0.78599, max_score= 0.78609
# High Score: iteration 4764, score=0.78666
# High Score: iteration 4765, score=0.78666
# High Score: iteration 4766, score=0.78666
# High Score: iteration 4767, score=0.78677
# High Score: iteration 4778, score=0.78688
# High Score: iteration 4779, score=0.78688
# High Score: iteration 4780, score=0.78699
# High Score: iteration 4794, score=0.78699
# High Score: iteration 4795, score=0.78720
# High Score: iteration 4796, score=0.78720
# High Score: iteration 4797, score=0.78721
# iteration 4800, score= 0.78668, max_score= 0.78721
# iteration 5000, score= 0.78557, max_score= 0.78721
# iteration 5200, score= 0.78489, max_score= 0.78721
# iteration 5400, score= 0.78597, max_score= 0.78721
# High Score: iteration 5459, score=0.78736
# High Score: iteration 5473, score=0.78736
# High Score: iteration 5474, score=0.78736
# High Score: iteration 5475, score=0.78736
# High Score: iteration 5476, score=0.78736
# High Score: iteration 5477, score=0.78736
# High Score: iteration 5478, score=0.78736
# High Score: iteration 5481, score=0.78746
# High Score: iteration 5482, score=0.78746
# iteration 5600, score= 0.78570, max_score= 0.78746
# iteration 5800, score= 0.78659, max_score= 0.78746
# iteration 6000, score= 0.78547, max_score= 0.78746
# iteration 6200, score= 0.78560, max_score= 0.78746
# iteration 6400, score= 0.78660, max_score= 0.78746
# iteration 6600, score= 0.78567, max_score= 0.78746
# iteration 6800, score= 0.78610, max_score= 0.78746
# High Score: iteration 6978, score=0.78759
# High Score: iteration 6979, score=0.78759
# High Score: iteration 6989, score=0.78770
# iteration 7000, score= 0.78750, max_score= 0.78770
# iteration 7200, score= 0.78563, max_score= 0.78770
# iteration 7400, score= 0.78554, max_score= 0.78770
# iteration 7600, score= 0.78547, max_score= 0.78770
# iteration 7800, score= 0.78613, max_score= 0.78770
# iteration 8000, score= 0.78604, max_score= 0.78770
# iteration 8200, score= 0.78647, max_score= 0.78770
# iteration 8400, score= 0.78628, max_score= 0.78770
# iteration 8600, score= 0.78700, max_score= 0.78770
# High Score: iteration 8608, score=0.78774
# High Score: iteration 8609, score=0.78774
# High Score: iteration 8611, score=0.78774
# High Score: iteration 8613, score=0.78774
# High Score: iteration 8614, score=0.78774
# High Score: iteration 8622, score=0.78775
# High Score: iteration 8623, score=0.78775
# High Score: iteration 8629, score=0.78786
# High Score: iteration 8630, score=0.78786
# High Score: iteration 8631, score=0.78786
# High Score: iteration 8634, score=0.78786
# High Score: iteration 8638, score=0.78806
# High Score: iteration 8641, score=0.78828
# High Score: iteration 8653, score=0.78869
# High Score: iteration 8670, score=0.78870
# High Score: iteration 8671, score=0.78870
# High Score: iteration 8673, score=0.78901
# High Score: iteration 8674, score=0.78902
# iteration 8800, score= 0.78848, max_score= 0.78902
# iteration 9000, score= 0.78806, max_score= 0.78902
# iteration 9200, score= 0.78776, max_score= 0.78902
# iteration 9400, score= 0.78775, max_score= 0.78902
# iteration 9600, score= 0.78786, max_score= 0.78902
# High Score: iteration 9776, score=0.78904
# High Score: iteration 9784, score=0.78904
# High Score: iteration 9785, score=0.78904
# iteration 9800, score= 0.78863, max_score= 0.78904
# iteration 10000, score= 0.78833, max_score= 0.78904
# iteration 10200, score= 0.78740, max_score= 0.78904
# iteration 10400, score= 0.78729, max_score= 0.78904
# iteration 10600, score= 0.78752, max_score= 0.78904
# iteration 10800, score= 0.78708, max_score= 0.78904
# iteration 11000, score= 0.78762, max_score= 0.78904
# iteration 11200, score= 0.78798, max_score= 0.78904
# iteration 11400, score= 0.78811, max_score= 0.78904
# iteration 11600, score= 0.78792, max_score= 0.78904
# iteration 11800, score= 0.78791, max_score= 0.78904
# High Score: iteration 11929, score=0.78906
#
# Training fold 3 with 1103 features...
# [LightGBM] [Info] Number of positive: 114075, number of negative: 326482
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.217905 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 187427
# [LightGBM] [Info] Number of data points in the train set: 440557, number of used features: 1095
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258934 -> initscore=-1.051519
# [LightGBM] [Info] Start training from score -1.051519
# iteration 0, score= 0.72304, max_score= 0.78500
# iteration 200, score= 0.77133, max_score= 0.78500
# iteration 400, score= 0.77570, max_score= 0.78500
# iteration 600, score= 0.77738, max_score= 0.78500
# iteration 800, score= 0.78227, max_score= 0.78500
# High Score: iteration 952, score=0.78512
# High Score: iteration 953, score=0.78533
# High Score: iteration 978, score=0.78596
# High Score: iteration 979, score=0.78598
# High Score: iteration 981, score=0.78630
# High Score: iteration 993, score=0.78634
# High Score: iteration 994, score=0.78634
# High Score: iteration 995, score=0.78646
# High Score: iteration 997, score=0.78646
# iteration 1000, score= 0.78552, max_score= 0.78646
# High Score: iteration 1028, score=0.78675
# High Score: iteration 1033, score=0.78700
# High Score: iteration 1035, score=0.78700
# High Score: iteration 1036, score=0.78701
# High Score: iteration 1037, score=0.78701
# High Score: iteration 1039, score=0.78701
# High Score: iteration 1040, score=0.78732
# High Score: iteration 1045, score=0.78734
# High Score: iteration 1046, score=0.78745
# High Score: iteration 1067, score=0.78762
# High Score: iteration 1091, score=0.78775
# High Score: iteration 1092, score=0.78775
# High Score: iteration 1117, score=0.78776
# High Score: iteration 1118, score=0.78786
# High Score: iteration 1119, score=0.78786
# High Score: iteration 1120, score=0.78797
# High Score: iteration 1154, score=0.78815
# High Score: iteration 1155, score=0.78859
# High Score: iteration 1156, score=0.78881
# High Score: iteration 1157, score=0.78912
# High Score: iteration 1163, score=0.78935
# High Score: iteration 1172, score=0.78939
# iteration 1200, score= 0.78874, max_score= 0.78939
# High Score: iteration 1213, score=0.78943
# High Score: iteration 1265, score=0.78968
# High Score: iteration 1266, score=0.78968
# High Score: iteration 1267, score=0.78968
# High Score: iteration 1268, score=0.78969
# High Score: iteration 1270, score=0.79022
# High Score: iteration 1325, score=0.79026
# High Score: iteration 1326, score=0.79037
# High Score: iteration 1327, score=0.79048
# High Score: iteration 1328, score=0.79048
# High Score: iteration 1329, score=0.79101
# High Score: iteration 1332, score=0.79101
# High Score: iteration 1333, score=0.79101
# iteration 1400, score= 0.79056, max_score= 0.79101
# High Score: iteration 1418, score=0.79113
# High Score: iteration 1419, score=0.79113
# High Score: iteration 1434, score=0.79116
# High Score: iteration 1435, score=0.79116
# High Score: iteration 1436, score=0.79158
# High Score: iteration 1437, score=0.79212
# High Score: iteration 1443, score=0.79213
# High Score: iteration 1446, score=0.79213
# High Score: iteration 1447, score=0.79213
# High Score: iteration 1448, score=0.79245
# High Score: iteration 1449, score=0.79245
# High Score: iteration 1450, score=0.79245
# High Score: iteration 1451, score=0.79246
# High Score: iteration 1468, score=0.79249
# High Score: iteration 1469, score=0.79249
# High Score: iteration 1470, score=0.79249
# High Score: iteration 1471, score=0.79249
# High Score: iteration 1472, score=0.79250
# High Score: iteration 1473, score=0.79303
# High Score: iteration 1474, score=0.79303
# High Score: iteration 1482, score=0.79305
# High Score: iteration 1484, score=0.79337
# High Score: iteration 1498, score=0.79371
# High Score: iteration 1499, score=0.79371
# High Score: iteration 1524, score=0.79377
# High Score: iteration 1526, score=0.79388
# High Score: iteration 1527, score=0.79388
# High Score: iteration 1529, score=0.79388
# iteration 1600, score= 0.79283, max_score= 0.79388
# High Score: iteration 1727, score=0.79408
# High Score: iteration 1729, score=0.79408
# High Score: iteration 1731, score=0.79409
# High Score: iteration 1732, score=0.79419
# High Score: iteration 1733, score=0.79504
# High Score: iteration 1768, score=0.79510
# High Score: iteration 1769, score=0.79510
# High Score: iteration 1787, score=0.79514
# High Score: iteration 1788, score=0.79514
# High Score: iteration 1789, score=0.79514
# iteration 1800, score= 0.79432, max_score= 0.79514
# High Score: iteration 1867, score=0.79541
# High Score: iteration 1994, score=0.79543
# iteration 2000, score= 0.79397, max_score= 0.79543
# iteration 2200, score= 0.79346, max_score= 0.79543
# iteration 2400, score= 0.79494, max_score= 0.79543
# High Score: iteration 2507, score=0.79547
# High Score: iteration 2508, score=0.79548
# High Score: iteration 2509, score=0.79548
# High Score: iteration 2513, score=0.79558
# High Score: iteration 2514, score=0.79559
# High Score: iteration 2515, score=0.79559
# High Score: iteration 2518, score=0.79559
# High Score: iteration 2520, score=0.79559
# High Score: iteration 2523, score=0.79559
# High Score: iteration 2524, score=0.79559
# High Score: iteration 2525, score=0.79559
# High Score: iteration 2526, score=0.79559
# iteration 2600, score= 0.79479, max_score= 0.79559
# High Score: iteration 2604, score=0.79586
# High Score: iteration 2687, score=0.79622
# High Score: iteration 2688, score=0.79622
# iteration 2800, score= 0.79504, max_score= 0.79622
# High Score: iteration 2934, score=0.79643
# High Score: iteration 2935, score=0.79643
# High Score: iteration 2936, score=0.79664
# High Score: iteration 2937, score=0.79664
# High Score: iteration 2938, score=0.79675
# iteration 3000, score= 0.79628, max_score= 0.79675
# High Score: iteration 3024, score=0.79683
# High Score: iteration 3025, score=0.79684
# High Score: iteration 3026, score=0.79684
# High Score: iteration 3027, score=0.79684
# High Score: iteration 3153, score=0.79756
# High Score: iteration 3183, score=0.79759
# High Score: iteration 3184, score=0.79759
# High Score: iteration 3190, score=0.79770
# High Score: iteration 3191, score=0.79802
# High Score: iteration 3192, score=0.79802
# High Score: iteration 3199, score=0.79812
# iteration 3200, score= 0.79823, max_score= 0.79812
# High Score: iteration 3200, score=0.79823
# High Score: iteration 3201, score=0.79844
# High Score: iteration 3202, score=0.79844
# High Score: iteration 3203, score=0.79844
# High Score: iteration 3204, score=0.79844
# High Score: iteration 3257, score=0.79849
# High Score: iteration 3258, score=0.79850
# High Score: iteration 3259, score=0.79850
# High Score: iteration 3260, score=0.79892
# High Score: iteration 3273, score=0.79893
# High Score: iteration 3276, score=0.79893
# High Score: iteration 3281, score=0.79894
# iteration 3400, score= 0.79828, max_score= 0.79894
# High Score: iteration 3421, score=0.79913
# High Score: iteration 3439, score=0.79915
# High Score: iteration 3440, score=0.79915
# High Score: iteration 3441, score=0.79915
# High Score: iteration 3442, score=0.79915
# High Score: iteration 3521, score=0.79921
# iteration 3600, score= 0.79775, max_score= 0.79921
# High Score: iteration 3681, score=0.79926
# High Score: iteration 3692, score=0.79926
# High Score: iteration 3693, score=0.79926
# High Score: iteration 3694, score=0.79927
# High Score: iteration 3695, score=0.79927
# High Score: iteration 3698, score=0.79927
# High Score: iteration 3699, score=0.79938
# High Score: iteration 3703, score=0.80001
# High Score: iteration 3705, score=0.80001
# High Score: iteration 3706, score=0.80001
# iteration 3800, score= 0.79868, max_score= 0.80001
# iteration 4000, score= 0.79935, max_score= 0.80001
# iteration 4200, score= 0.79834, max_score= 0.80001
# iteration 4400, score= 0.79833, max_score= 0.80001
# iteration 4600, score= 0.79828, max_score= 0.80001
# iteration 4800, score= 0.79779, max_score= 0.80001
# iteration 5000, score= 0.79899, max_score= 0.80001
# High Score: iteration 5103, score=0.80010
# High Score: iteration 5141, score=0.80012
# High Score: iteration 5143, score=0.80033
# High Score: iteration 5144, score=0.80033
# High Score: iteration 5145, score=0.80033
# High Score: iteration 5151, score=0.80043
# High Score: iteration 5178, score=0.80045
# High Score: iteration 5179, score=0.80045
# High Score: iteration 5180, score=0.80045
# High Score: iteration 5181, score=0.80045
# High Score: iteration 5186, score=0.80055
# High Score: iteration 5187, score=0.80066
# High Score: iteration 5188, score=0.80066
# High Score: iteration 5189, score=0.80066
# iteration 5200, score= 0.79971, max_score= 0.80066
# High Score: iteration 5241, score=0.80077
# High Score: iteration 5243, score=0.80077
# High Score: iteration 5246, score=0.80077
# High Score: iteration 5247, score=0.80087
# High Score: iteration 5310, score=0.80099
# High Score: iteration 5311, score=0.80099
# High Score: iteration 5313, score=0.80099
# High Score: iteration 5314, score=0.80099
# High Score: iteration 5316, score=0.80099
# High Score: iteration 5336, score=0.80110
# High Score: iteration 5339, score=0.80130
# High Score: iteration 5347, score=0.80153
# High Score: iteration 5348, score=0.80163
# High Score: iteration 5357, score=0.80174
# iteration 5400, score= 0.80133, max_score= 0.80174
# High Score: iteration 5444, score=0.80175
# iteration 5600, score= 0.80062, max_score= 0.80175
# iteration 5800, score= 0.80011, max_score= 0.80175
# iteration 6000, score= 0.80077, max_score= 0.80175
# iteration 6200, score= 0.80039, max_score= 0.80175
# iteration 6400, score= 0.80033, max_score= 0.80175
# High Score: iteration 6455, score=0.80182
# High Score: iteration 6574, score=0.80184
# High Score: iteration 6580, score=0.80205
# High Score: iteration 6583, score=0.80205
# iteration 6600, score= 0.80111, max_score= 0.80205
# High Score: iteration 6765, score=0.80211
# High Score: iteration 6768, score=0.80211
# High Score: iteration 6770, score=0.80211
# iteration 6800, score= 0.80074, max_score= 0.80211
# High Score: iteration 6879, score=0.80212
# High Score: iteration 6880, score=0.80212
# iteration 7000, score= 0.80118, max_score= 0.80212
# High Score: iteration 7051, score=0.80215
# High Score: iteration 7052, score=0.80215
# High Score: iteration 7053, score=0.80215
# High Score: iteration 7054, score=0.80215
# High Score: iteration 7055, score=0.80215
# High Score: iteration 7056, score=0.80215
# High Score: iteration 7058, score=0.80215
# High Score: iteration 7060, score=0.80215
# High Score: iteration 7066, score=0.80215
# High Score: iteration 7070, score=0.80215
# High Score: iteration 7081, score=0.80216
# High Score: iteration 7082, score=0.80226
# iteration 7200, score= 0.80131, max_score= 0.80226
# iteration 7400, score= 0.80010, max_score= 0.80226
# iteration 7600, score= 0.80141, max_score= 0.80226
# High Score: iteration 7628, score=0.80226
# High Score: iteration 7629, score=0.80226
# iteration 7800, score= 0.80163, max_score= 0.80226
# iteration 8000, score= 0.80166, max_score= 0.80226
# High Score: iteration 8143, score=0.80233
# High Score: iteration 8148, score=0.80243
# High Score: iteration 8149, score=0.80254
# High Score: iteration 8150, score=0.80264
# High Score: iteration 8155, score=0.80274
# High Score: iteration 8163, score=0.80275
# High Score: iteration 8164, score=0.80275
# iteration 8200, score= 0.80222, max_score= 0.80275
# iteration 8400, score= 0.80189, max_score= 0.80275
# iteration 8600, score= 0.80114, max_score= 0.80275
# iteration 8800, score= 0.80230, max_score= 0.80275
# iteration 9000, score= 0.80114, max_score= 0.80275
# iteration 9200, score= 0.80061, max_score= 0.80275
# iteration 9400, score= 0.80137, max_score= 0.80275
# iteration 9600, score= 0.80033, max_score= 0.80275
# iteration 9800, score= 0.80211, max_score= 0.80275
# iteration 10000, score= 0.80146, max_score= 0.80275
# iteration 10200, score= 0.80124, max_score= 0.80275
# iteration 10400, score= 0.80200, max_score= 0.80275
# iteration 10600, score= 0.80177, max_score= 0.80275
# iteration 10800, score= 0.80105, max_score= 0.80275
# iteration 11000, score= 0.80221, max_score= 0.80275
# iteration 11200, score= 0.80233, max_score= 0.80275
# iteration 11400, score= 0.80221, max_score= 0.80275
# iteration 11600, score= 0.80223, max_score= 0.80275
# iteration 11800, score= 0.80183, max_score= 0.80275
#
# Training fold 4 with 1103 features...
# [LightGBM] [Info] Number of positive: 114075, number of negative: 326482
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 1.144003 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 187461
# [LightGBM] [Info] Number of data points in the train set: 440557, number of used features: 1095
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258934 -> initscore=-1.051519
# [LightGBM] [Info] Start training from score -1.051519
# iteration 0, score= 0.71640, max_score= 0.78500
# iteration 200, score= 0.76389, max_score= 0.78500
# iteration 400, score= 0.76832, max_score= 0.78500
# iteration 600, score= 0.77222, max_score= 0.78500
# iteration 800, score= 0.77909, max_score= 0.78500
# iteration 1000, score= 0.78286, max_score= 0.78500
# High Score: iteration 1071, score=0.78525
# High Score: iteration 1075, score=0.78527
# High Score: iteration 1076, score=0.78527
# High Score: iteration 1080, score=0.78528
# High Score: iteration 1082, score=0.78529
# High Score: iteration 1083, score=0.78530
# High Score: iteration 1085, score=0.78531
# High Score: iteration 1086, score=0.78552
# High Score: iteration 1087, score=0.78553
# High Score: iteration 1088, score=0.78564
# High Score: iteration 1098, score=0.78572
# High Score: iteration 1101, score=0.78626
# High Score: iteration 1102, score=0.78637
# High Score: iteration 1145, score=0.78661
# iteration 1200, score= 0.78502, max_score= 0.78661
# High Score: iteration 1272, score=0.78690
# High Score: iteration 1299, score=0.78698
# High Score: iteration 1300, score=0.78698
# High Score: iteration 1301, score=0.78698
# High Score: iteration 1307, score=0.78709
# High Score: iteration 1308, score=0.78709
# High Score: iteration 1309, score=0.78720
# High Score: iteration 1310, score=0.78721
# High Score: iteration 1311, score=0.78721
# High Score: iteration 1399, score=0.78737
# iteration 1400, score= 0.78716, max_score= 0.78737
# High Score: iteration 1401, score=0.78790
# High Score: iteration 1402, score=0.78790
# High Score: iteration 1403, score=0.78791
# High Score: iteration 1437, score=0.78798
# High Score: iteration 1438, score=0.78830
# High Score: iteration 1439, score=0.78830
# High Score: iteration 1440, score=0.78830
# High Score: iteration 1441, score=0.78830
# High Score: iteration 1442, score=0.78830
# High Score: iteration 1443, score=0.78830
# High Score: iteration 1444, score=0.78851
# High Score: iteration 1445, score=0.78852
# High Score: iteration 1446, score=0.78852
# High Score: iteration 1447, score=0.78852
# High Score: iteration 1448, score=0.78852
# High Score: iteration 1449, score=0.78853
# High Score: iteration 1450, score=0.78853
# High Score: iteration 1453, score=0.78854
# High Score: iteration 1454, score=0.78855
# High Score: iteration 1455, score=0.78855
# High Score: iteration 1456, score=0.78855
# High Score: iteration 1457, score=0.78855
# High Score: iteration 1458, score=0.78855
# High Score: iteration 1459, score=0.78855
# High Score: iteration 1460, score=0.78855
# High Score: iteration 1461, score=0.78855
# High Score: iteration 1462, score=0.78855
# High Score: iteration 1463, score=0.78855
# High Score: iteration 1464, score=0.78855
# High Score: iteration 1465, score=0.78856
# High Score: iteration 1467, score=0.78856
# High Score: iteration 1488, score=0.78860
# High Score: iteration 1489, score=0.78861
# High Score: iteration 1493, score=0.78861
# High Score: iteration 1494, score=0.78872
# High Score: iteration 1511, score=0.78875
# High Score: iteration 1515, score=0.78898
# High Score: iteration 1516, score=0.78898
# High Score: iteration 1517, score=0.78898
# High Score: iteration 1518, score=0.78899
# High Score: iteration 1523, score=0.78922
# High Score: iteration 1560, score=0.78954
# High Score: iteration 1561, score=0.78975
# High Score: iteration 1589, score=0.78983
# High Score: iteration 1598, score=0.78986
# High Score: iteration 1599, score=0.78986
# iteration 1600, score= 0.78986, max_score= 0.78986
# High Score: iteration 1600, score=0.78986
# High Score: iteration 1603, score=0.78998
# High Score: iteration 1604, score=0.79009
# High Score: iteration 1614, score=0.79033
# High Score: iteration 1615, score=0.79033
# High Score: iteration 1616, score=0.79033
# High Score: iteration 1617, score=0.79033
# High Score: iteration 1618, score=0.79033
# High Score: iteration 1619, score=0.79033
# High Score: iteration 1622, score=0.79034
# High Score: iteration 1623, score=0.79045
# High Score: iteration 1624, score=0.79077
# High Score: iteration 1625, score=0.79088
# High Score: iteration 1632, score=0.79101
# High Score: iteration 1633, score=0.79112
# High Score: iteration 1634, score=0.79112
# High Score: iteration 1635, score=0.79185
# High Score: iteration 1641, score=0.79219
# High Score: iteration 1648, score=0.79221
# High Score: iteration 1649, score=0.79232
# High Score: iteration 1652, score=0.79244
# High Score: iteration 1654, score=0.79244
# High Score: iteration 1655, score=0.79266
# High Score: iteration 1656, score=0.79266
# High Score: iteration 1657, score=0.79266
# High Score: iteration 1658, score=0.79308
# High Score: iteration 1659, score=0.79308
# iteration 1800, score= 0.79263, max_score= 0.79308
# High Score: iteration 1845, score=0.79323
# High Score: iteration 1846, score=0.79344
# High Score: iteration 1847, score=0.79344
# High Score: iteration 1848, score=0.79344
# High Score: iteration 1850, score=0.79345
# High Score: iteration 1851, score=0.79345
# High Score: iteration 1853, score=0.79367
# High Score: iteration 1854, score=0.79367
# High Score: iteration 1857, score=0.79368
# High Score: iteration 1950, score=0.79376
# High Score: iteration 1951, score=0.79377
# High Score: iteration 1952, score=0.79377
# High Score: iteration 1996, score=0.79387
# High Score: iteration 1998, score=0.79387
# High Score: iteration 1999, score=0.79387
# iteration 2000, score= 0.79346, max_score= 0.79387
# High Score: iteration 2024, score=0.79412
# High Score: iteration 2025, score=0.79412
# High Score: iteration 2029, score=0.79414
# High Score: iteration 2030, score=0.79414
# High Score: iteration 2031, score=0.79414
# High Score: iteration 2056, score=0.79480
# High Score: iteration 2058, score=0.79480
# High Score: iteration 2068, score=0.79481
# High Score: iteration 2069, score=0.79491
# High Score: iteration 2070, score=0.79491
# High Score: iteration 2071, score=0.79502
# High Score: iteration 2072, score=0.79502
# High Score: iteration 2073, score=0.79502
# iteration 2200, score= 0.79454, max_score= 0.79502
# High Score: iteration 2209, score=0.79507
# High Score: iteration 2258, score=0.79515
# High Score: iteration 2285, score=0.79530
# High Score: iteration 2288, score=0.79530
# High Score: iteration 2289, score=0.79552
# High Score: iteration 2290, score=0.79552
# iteration 2400, score= 0.79490, max_score= 0.79552
# High Score: iteration 2463, score=0.79592
# High Score: iteration 2465, score=0.79592
# High Score: iteration 2498, score=0.79616
# High Score: iteration 2500, score=0.79616
# High Score: iteration 2501, score=0.79616
# iteration 2600, score= 0.79532, max_score= 0.79616
# High Score: iteration 2603, score=0.79618
# High Score: iteration 2662, score=0.79633
# High Score: iteration 2663, score=0.79634
# High Score: iteration 2664, score=0.79634
# High Score: iteration 2675, score=0.79645
# High Score: iteration 2695, score=0.79656
# High Score: iteration 2696, score=0.79656
# High Score: iteration 2710, score=0.79657
# High Score: iteration 2760, score=0.79662
# High Score: iteration 2761, score=0.79662
# High Score: iteration 2762, score=0.79672
# High Score: iteration 2783, score=0.79685
# High Score: iteration 2784, score=0.79696
# iteration 2800, score= 0.79612, max_score= 0.79696
# High Score: iteration 2815, score=0.79698
# High Score: iteration 2816, score=0.79698
# High Score: iteration 2821, score=0.79698
# High Score: iteration 2822, score=0.79699
# High Score: iteration 2823, score=0.79699
# High Score: iteration 2827, score=0.79710
# High Score: iteration 2828, score=0.79710
# High Score: iteration 2833, score=0.79721
# High Score: iteration 2848, score=0.79776
# High Score: iteration 2877, score=0.79799
# High Score: iteration 2878, score=0.79799
# High Score: iteration 2906, score=0.79802
# High Score: iteration 2960, score=0.79807
# High Score: iteration 2963, score=0.79818
# High Score: iteration 2986, score=0.79831
# High Score: iteration 2987, score=0.79831
# High Score: iteration 2988, score=0.79831
# High Score: iteration 2989, score=0.79831
# High Score: iteration 2993, score=0.79853
# High Score: iteration 2994, score=0.79863
# iteration 3000, score= 0.79769, max_score= 0.79863
# High Score: iteration 3164, score=0.79866
# High Score: iteration 3165, score=0.79866
# High Score: iteration 3166, score=0.79866
# High Score: iteration 3183, score=0.79868
# High Score: iteration 3184, score=0.79868
# High Score: iteration 3185, score=0.79868
# High Score: iteration 3186, score=0.79868
# High Score: iteration 3190, score=0.79889
# High Score: iteration 3193, score=0.79900
# High Score: iteration 3199, score=0.79901
# iteration 3200, score= 0.79891, max_score= 0.79901
# iteration 3400, score= 0.79736, max_score= 0.79901
# iteration 3600, score= 0.79759, max_score= 0.79901
# High Score: iteration 3673, score=0.79909
# High Score: iteration 3674, score=0.79909
# High Score: iteration 3765, score=0.79927
# High Score: iteration 3798, score=0.79929
# iteration 3800, score= 0.79919, max_score= 0.79929
# High Score: iteration 3818, score=0.79940
# High Score: iteration 3819, score=0.79940
# High Score: iteration 3820, score=0.79940
# High Score: iteration 3823, score=0.79951
# High Score: iteration 3824, score=0.79951
# High Score: iteration 3825, score=0.79951
# High Score: iteration 3826, score=0.79951
# High Score: iteration 3827, score=0.79951
# High Score: iteration 3828, score=0.79951
# High Score: iteration 3831, score=0.79951
# High Score: iteration 3846, score=0.79972
# High Score: iteration 3847, score=0.79983
# High Score: iteration 3848, score=0.79983
# High Score: iteration 3851, score=0.80004
# High Score: iteration 3856, score=0.80004
# High Score: iteration 3935, score=0.80031
# iteration 4000, score= 0.79981, max_score= 0.80031
# iteration 4200, score= 0.80001, max_score= 0.80031
# iteration 4400, score= 0.80007, max_score= 0.80031
# High Score: iteration 4405, score=0.80049
# High Score: iteration 4406, score=0.80060
# High Score: iteration 4408, score=0.80060
# High Score: iteration 4412, score=0.80091
# High Score: iteration 4486, score=0.80093
# High Score: iteration 4487, score=0.80093
# High Score: iteration 4490, score=0.80125
# High Score: iteration 4491, score=0.80125
# High Score: iteration 4494, score=0.80125
# High Score: iteration 4496, score=0.80125
# High Score: iteration 4497, score=0.80146
# High Score: iteration 4499, score=0.80146
# High Score: iteration 4559, score=0.80147
# High Score: iteration 4560, score=0.80158
# High Score: iteration 4561, score=0.80158
# High Score: iteration 4562, score=0.80158
# High Score: iteration 4563, score=0.80158
# High Score: iteration 4564, score=0.80168
# High Score: iteration 4572, score=0.80179
# High Score: iteration 4573, score=0.80180
# High Score: iteration 4574, score=0.80180
# iteration 4600, score= 0.80107, max_score= 0.80180
# High Score: iteration 4644, score=0.80202
# High Score: iteration 4645, score=0.80212
# High Score: iteration 4646, score=0.80212
# High Score: iteration 4647, score=0.80212
# High Score: iteration 4649, score=0.80223
# High Score: iteration 4653, score=0.80223
# High Score: iteration 4654, score=0.80223
# High Score: iteration 4701, score=0.80223
# High Score: iteration 4702, score=0.80223
# High Score: iteration 4703, score=0.80223
# High Score: iteration 4704, score=0.80223
# High Score: iteration 4705, score=0.80223
# High Score: iteration 4706, score=0.80224
# High Score: iteration 4707, score=0.80224
# High Score: iteration 4708, score=0.80224
# High Score: iteration 4709, score=0.80224
# High Score: iteration 4714, score=0.80224
# High Score: iteration 4718, score=0.80224
# High Score: iteration 4734, score=0.80225
# High Score: iteration 4735, score=0.80225
# High Score: iteration 4749, score=0.80226
# High Score: iteration 4751, score=0.80226
# High Score: iteration 4762, score=0.80226
# High Score: iteration 4794, score=0.80227
# iteration 4800, score= 0.80186, max_score= 0.80227
# High Score: iteration 4813, score=0.80228
# High Score: iteration 4815, score=0.80228
# High Score: iteration 4817, score=0.80229
# High Score: iteration 4818, score=0.80229
# High Score: iteration 4822, score=0.80229
# High Score: iteration 4823, score=0.80229
# High Score: iteration 4824, score=0.80229
# High Score: iteration 4842, score=0.80229
# High Score: iteration 4843, score=0.80229
# High Score: iteration 4877, score=0.80230
# High Score: iteration 4878, score=0.80230
# High Score: iteration 4882, score=0.80230
# High Score: iteration 4884, score=0.80231
# High Score: iteration 4885, score=0.80231
# High Score: iteration 4915, score=0.80231
# High Score: iteration 4916, score=0.80231
# High Score: iteration 4918, score=0.80231
# High Score: iteration 4919, score=0.80231
# High Score: iteration 4920, score=0.80232
# High Score: iteration 4923, score=0.80232
# High Score: iteration 4924, score=0.80232
# High Score: iteration 4927, score=0.80232
# High Score: iteration 4928, score=0.80253
# High Score: iteration 4929, score=0.80253
# High Score: iteration 4931, score=0.80253
# High Score: iteration 4936, score=0.80253
# High Score: iteration 4939, score=0.80253
# High Score: iteration 4940, score=0.80253
# High Score: iteration 4942, score=0.80253
# High Score: iteration 4943, score=0.80263
# High Score: iteration 4944, score=0.80263
# High Score: iteration 4945, score=0.80263
# High Score: iteration 4946, score=0.80274
# High Score: iteration 4949, score=0.80337
# iteration 5000, score= 0.80274, max_score= 0.80337
# High Score: iteration 5020, score=0.80349
# High Score: iteration 5021, score=0.80349
# High Score: iteration 5022, score=0.80349
# High Score: iteration 5024, score=0.80349
# High Score: iteration 5025, score=0.80360
# High Score: iteration 5026, score=0.80360
# High Score: iteration 5170, score=0.80361
# High Score: iteration 5175, score=0.80372
# High Score: iteration 5176, score=0.80393
# High Score: iteration 5177, score=0.80403
# iteration 5200, score= 0.80286, max_score= 0.80403
# High Score: iteration 5232, score=0.80424
# High Score: iteration 5233, score=0.80435
# High Score: iteration 5237, score=0.80445
# High Score: iteration 5239, score=0.80445
# iteration 5400, score= 0.80363, max_score= 0.80445
# iteration 5600, score= 0.80333, max_score= 0.80445
# iteration 5800, score= 0.80348, max_score= 0.80445
# iteration 6000, score= 0.80337, max_score= 0.80445
# iteration 6200, score= 0.80350, max_score= 0.80445
# iteration 6400, score= 0.80297, max_score= 0.80445
# iteration 6600, score= 0.80246, max_score= 0.80445
# iteration 6800, score= 0.80147, max_score= 0.80445
# iteration 7000, score= 0.80224, max_score= 0.80445
# iteration 7200, score= 0.80216, max_score= 0.80445
# iteration 7400, score= 0.80252, max_score= 0.80445
# iteration 7600, score= 0.80169, max_score= 0.80445
# iteration 7800, score= 0.80177, max_score= 0.80445
# iteration 8000, score= 0.80125, max_score= 0.80445
# iteration 8200, score= 0.80138, max_score= 0.80445
# iteration 8400, score= 0.80173, max_score= 0.80445
# iteration 8600, score= 0.80163, max_score= 0.80445
# iteration 8800, score= 0.80122, max_score= 0.80445
# iteration 9000, score= 0.80112, max_score= 0.80445
# iteration 9200, score= 0.80208, max_score= 0.80445
# iteration 9400, score= 0.80102, max_score= 0.80445
# iteration 9600, score= 0.80269, max_score= 0.80445
# iteration 9800, score= 0.80165, max_score= 0.80445
# iteration 10000, score= 0.80102, max_score= 0.80445
# iteration 10200, score= 0.80197, max_score= 0.80445
# iteration 10400, score= 0.80114, max_score= 0.80445
# iteration 10600, score= 0.80081, max_score= 0.80445
# iteration 10800, score= 0.80187, max_score= 0.80445
# iteration 11000, score= 0.80104, max_score= 0.80445
# iteration 11200, score= 0.80157, max_score= 0.80445
# iteration 11400, score= 0.80054, max_score= 0.80445
# iteration 11600, score= 0.79969, max_score= 0.80445
# iteration 11800, score= 0.79939, max_score= 0.80445

# %%
# grid  = list(ParameterGrid(params))
# len_grid = len(grid)
# for run, parameters in enumerate(grid):
#     print('-' * 50)
#     print(run, len_grid, parameters)
#     train_and_evaluate(x_train,y_train, val, parameters)
