# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_data = pd.read_pickle('Data/train_data.pkl')
train_data.shape
# Out:
# (5531451, 189)

# %%
train_data.drop(columns=['S_2'], axis=1, inplace=True)
to_remove_features = []
categorical_features = ['B_30', 'B_31', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120', 'D_126', 'D_63', 'D_64', 'D_66', 'D_68']
numerical_features = list(set(train_data.columns).difference(set(categorical_features)))

for i in to_remove_features:
    numerical_features.remove(i)

# %%
for i in numerical_features:
    
    df = train_data[train_data[i].notnull()][i]
    min_df = df.min()
    if min_df < 0:
        df = df - min_df + 0.00001
    else:
        df = df + 0.00001
        
    plt.hist(df, alpha = 0.4, bins = 20)
    plt.hist(np.log(df), alpha = 0.4, bins = 20)
    plt.title(i)
    plt.show()
    plt.clf()

# %%
i = 'B_37'
df = train_data[train_data[i].notnull()][i]
min_df = df.min()
df = df - min_df + 1.0

df = df.sort_values()
df
# Out:
# customer_ID
# 6686ebd286c0b1a97852b2a91b899617aaedb4fc0a90bd29a67860b5da497e5d    1.000000
# 2c4818bd3bfa22ffff2e95e7b04255ac6bf4ae997c88d8e5c2116b1c11689cf6    3.289062
# 3895be22e08edf1a45a77b4ca2160ee5de28d40d4c6fae43eee673924f32d43a    4.460938
# 7ac3c06ad110f082a7caf7cd224139501463a9cff99e42b058ce969fa6ec39e5    4.496094
# 0a4e2ba6d33c8e2ad0867a629e461dfd0639c865325f88378610a3e3f23f3b1a    4.804688
#                                                                       ...
# f6d728b656b6a7257ae535a45dbc1bedeea4739b9ba49db916241f206fa96288    9.937500
# 0cf55804a1f4079176a31b6d8422d4c9999f9411a9225ba043fda3d50ef3fec0    9.937500
# a10c6a1236d9b783095e843161781c402b3c86707475310e6098f7b94f75aec4    9.937500
# 8cb4206740cebc1beee84df62a0c6ad85765d0fe2705d293feeb1fa4a87bdf3d    9.937500
# 2bb9a20b2ff71f13588855250841e643175759c33f6545b1655aea6fd86ca8c3    9.937500
# Name: B_37, Length: 5531395, dtype: float16

# %%
np.log(df)
# Out:
# customer_ID
# 6686ebd286c0b1a97852b2a91b899617aaedb4fc0a90bd29a67860b5da497e5d    0.000000
# 2c4818bd3bfa22ffff2e95e7b04255ac6bf4ae997c88d8e5c2116b1c11689cf6    1.190430
# 3895be22e08edf1a45a77b4ca2160ee5de28d40d4c6fae43eee673924f32d43a    1.495117
# 7ac3c06ad110f082a7caf7cd224139501463a9cff99e42b058ce969fa6ec39e5    1.502930
# 0a4e2ba6d33c8e2ad0867a629e461dfd0639c865325f88378610a3e3f23f3b1a    1.569336
#                                                                       ...
# f6d728b656b6a7257ae535a45dbc1bedeea4739b9ba49db916241f206fa96288    2.296875
# 0cf55804a1f4079176a31b6d8422d4c9999f9411a9225ba043fda3d50ef3fec0    2.296875
# a10c6a1236d9b783095e843161781c402b3c86707475310e6098f7b94f75aec4    2.296875
# 8cb4206740cebc1beee84df62a0c6ad85765d0fe2705d293feeb1fa4a87bdf3d    2.296875
# 2bb9a20b2ff71f13588855250841e643175759c33f6545b1655aea6fd86ca8c3    2.296875
# Name: B_37, Length: 5531395, dtype: float16
